# %%
import sympy as sp
import numpy as np
from sympy import polylog
from observations.spaces import StringObs, ActionSpace
from envs.gym_env import PolyLogLinExpr
from sb3_contrib import TRPO
from model.monitor_utils import evaluate_model
from rewards.reward_func import StepReward

# %%
if __name__ == '__main__':

    # Episode length
    max_step = 50

    # Reward function to use
    reward_func = StepReward(len_pen=0.00 ,num_terms_pen=0, active_pen=False, simple_reward=1, pen_cycle=False)

    # Define the environment and spaces
    x = sp.Symbol('x')
    exprtest = polylog(2, x)
    obs_space = StringObs(exprtest, 512, one_hot_encode=True, numeral_decomp=True, prev_st_info=True,
                          reduced_graph=True)
    act_space = ActionSpace(['inversion', 'reflection', 'cyclic', 'duplication'])
    rng = np.random.RandomState(1)
    env = PolyLogLinExpr(max_step, reward_func, obs_space, act_space, rng)

    # Load the model
    rl_model = TRPO.load("/home/stringer/下载/data_and_model/RL Agents/One_hot_cyclic_penalty.zip")

    # Load the test set
    start_set = "/home/stringer/下载/data_and_model/test_data.txt"

    # Evaluate the model and print the statistics
    evaluate_model(rl_model, env, initial_start_set=start_set, deterministic=True, num_runs=1, verbose=False,
                     random_agent=False, distrib_info=True)
# Out:
# On set :
# Doing expression 0
# Doing expression 10
# Doing expression 20
# Doing expression 30
# Doing expression 40
# Doing expression 50
# Doing expression 60
# Doing expression 70
# Doing expression 80
# Doing expression 90
# Doing expression 100
# Doing expression 110
# Doing expression 120
# Doing expression 130
# Doing expression 140
# Doing expression 150
# Doing expression 160
# Doing expression 170
# Doing expression 180
# Doing expression 190
# Doing expression 200
# Doing expression 210
# Doing expression 220
# Doing expression 230
# Doing expression 240
# Doing expression 250
# Doing expression 260
# Doing expression 270
# Doing expression 280
# Doing expression 290
# Doing expression 300
# Doing expression 310
# Doing expression 320
# Doing expression 330
# Doing expression 340
# Doing expression 350
# Doing expression 360
# Doing expression 370
# Doing expression 380
# Doing expression 390
# Doing expression 400
# Doing expression 410
# Doing expression 420
# Doing expression 430
# Doing expression 440
# Doing expression 450
# Doing expression 460
# Doing expression 470
# Doing expression 480
# Doing expression 490
# Doing expression 500
# Doing expression 510
# Doing expression 520
# Doing expression 530
# Doing expression 540
# Doing expression 550
# Doing expression 560
# Doing expression 570
# Doing expression 580
# Doing expression 590
# Doing expression 600
# Doing expression 610
# Doing expression 620
# Doing expression 630
# Doing expression 640
# Doing expression 650
# Doing expression 660
# Doing expression 670
# Doing expression 680
# Doing expression 690
# Doing expression 700
# Doing expression 710
# Doing expression 720
# Doing expression 730
# Doing expression 740
# Doing expression 750
# Doing expression 760
# Doing expression 770
# Doing expression 780
# Doing expression 790
# Doing expression 800
# Doing expression 810
# Doing expression 820
# Doing expression 830
# Doing expression 840
# Doing expression 850
# Doing expression 860
# Doing expression 870
# Doing expression 880
# Doing expression 890
# Doing expression 900
# Doing expression 910
# Doing expression 920
# Doing expression 930
# Doing expression 940
# Doing expression 950
# Doing expression 960
# Doing expression 970
# Doing expression 980
# Doing expression 990
# Doing expression 1000
# Doing expression 1010
# Doing expression 1020
# Doing expression 1030
# Doing expression 1040
# Doing expression 1050
# Doing expression 1060
# Doing expression 1070
# Doing expression 1080
# Doing expression 1090
# Doing expression 1100
# Doing expression 1110
# Doing expression 1120
# Doing expression 1130
# Doing expression 1140
# Doing expression 1150
# Doing expression 1160
# Doing expression 1170
# Doing expression 1180
# Doing expression 1190
# Doing expression 1200
# Doing expression 1210
# Doing expression 1220
# Doing expression 1230
# Doing expression 1240
# Doing expression 1250
# Doing expression 1260
# Doing expression 1270
# Doing expression 1280
# Doing expression 1290
# Doing expression 1300
# Doing expression 1310
# Doing expression 1320
# Doing expression 1330
# Doing expression 1340
# Doing expression 1350
# Doing expression 1360
# Doing expression 1370
# Doing expression 1380
# Doing expression 1390
# Doing expression 1400
# Doing expression 1410
# Doing expression 1420
# Doing expression 1430
# Doing expression 1440
# Doing expression 1450
# Doing expression 1460
# Doing expression 1470
# Doing expression 1480
# Mean Total reward: 1.8521269412559083
# Mean Total Steps: 25.96556380823768
# Mean Total Non cyclic Steps: 17.095205941931127
# Action distribution: {'0': 10983, '1': 4382, '2': 13137, '3': 9953}
# Mean Total Steps for solved: 9.870349492671927
# Mean Total Non cyclic Steps for solved: 7.3585118376550165
# Action distribution for solved: {'0': 3048, '1': 1675, '2': 2228, '3': 1804}
# Mean final number of polylogs: 2.1991897366644158
# Mean initial number of polylogs : 4.87711006076975
# Mean final number of polylogs extra: 2.1991897366644158
# Mean final length of expression: 91.03646185010129
# Mean initial length of expression: 140.17960837272113
# Mean final length of expression extra: 89.03646185010129
# Found 0 cyclic trajectories. So for 0 % of the expressions:
# Distribution for solved by initial length: {'0': 0.6, '1': 0, '2': 0, '3': 0}
# Distribution for solved in trajectory by initial length: {'0': 0.6, '1': 0, '2': 0, '3': 0}
# Distribution for solved: {'s1t1': 99.0, 's2t1': 83.0, 's2t2': 88.0, 's3t1': 68.0, 's3t2': 80.0, 's3t3': 70.0, 's4t1': 44.33, 's4t2': 55.0, 's4t3': 57.0, 's4t4': 56.0, 's5t1': 37.89, 's5t2': 48.48, 's6t1': 33.67, 's6t2': 36.36, 's7t1': 37.63}
# Distribution for solved in trajectory: {'s1t1': 99.0, 's2t1': 83.0, 's2t2': 88.0, 's3t1': 68.0, 's3t2': 80.0, 's3t3': 70.0, 's4t1': 44.33, 's4t2': 55.0, 's4t3': 57.0, 's4t4': 56.0, 's5t1': 37.89, 's5t2': 48.48, 's6t1': 33.67, 's6t2': 36.36, 's7t1': 37.63}
# Distribution for solved (non cyclic) steps: {'s1t1': 2.65, 's2t1': 4.24, 's2t2': 4.75, 's3t1': 5.59, 's3t2': 7.78, 's3t3': 8.67, 's4t1': 7.47, 's4t2': 9.04, 's4t3': 10.58, 's4t4': 10.8, 's5t1': 9.89, 's5t2': 10.46, 's6t1': 10.21, 's6t2': 10.72, 's7t1': 7.97}
# Distribution for nodes visited: {'s1t1': 3.05, 's2t1': 8.34, 's2t2': 8.24, 's3t1': 14.37, 's3t2': 12.98, 's3t3': 15.94, 's4t1': 20.97938144329897, 's4t2': 20.48, 's4t3': 19.88, 's4t4': 19.4, 's5t1': 22.378947368421052, 's5t2': 22.616161616161616, 's6t1': 23.540816326530614, 's6t2': 22.91919191919192, 's7t1': 22.301075268817204}
# Solved expressions, num polylogs 59 %
# Solved expressions, num words 59 %

# %%
if __name__ == '__main__':

    # Episode length
    max_step = 50

    # Reward function to use
    reward_func = StepReward(len_pen=0.00, num_terms_pen=0.0, active_pen=False, simple_reward=1, pen_cycle=False)

    # Define the environment and spaces
    x = sp.Symbol('x')
    exprtest = polylog(2, x)
    obs_space = StringObs(exprtest, 512, one_hot_encode=True, numeral_decomp=True, prev_st_info=True,
                          reduced_graph=True)
    act_space = ActionSpace(['inversion', 'reflection', 'cyclic', 'duplication'])
    rng = np.random.RandomState(1)
    env = PolyLogLinExpr(max_step, reward_func, obs_space, act_space, rng)

    # Load the model
    rl_model = TRPO.load("/home/stringer/Downloads/RL_agents_all/RL Agents/One_hot_no_cyclic_penalty.zip")

    # Load the test set
    start_set = "/home/stringer/Downloads/rl_data_dilogs/test_data.txt"

    # Evaluate the model and print the statistics
    evaluate_model(rl_model, env, initial_start_set=start_set, deterministic=True, num_runs=1, verbose=False,
                   random_agent=False, distrib_info=True)
# Out:
# On set :
# Doing expression 0
# Doing expression 10
# Doing expression 20
# Doing expression 30
# Doing expression 40
# Doing expression 50
# Doing expression 60
# Doing expression 70
# Doing expression 80
# Doing expression 90
# Doing expression 100
# Doing expression 110
# Doing expression 120
# Doing expression 130
# Doing expression 140
# Doing expression 150
# Doing expression 160
# Doing expression 170
# Doing expression 180
# Doing expression 190
# Doing expression 200
# Doing expression 210
# Doing expression 220
# Doing expression 230
# Doing expression 240
# Doing expression 250
# Doing expression 260
# Doing expression 270
# Doing expression 280
# Doing expression 290
# Doing expression 300
# Doing expression 310
# Doing expression 320
# Doing expression 330
# Doing expression 340
# Doing expression 350
# Doing expression 360
# Doing expression 370
# Doing expression 380
# Doing expression 390
# Doing expression 400
# Doing expression 410
# Doing expression 420
# Doing expression 430
# Doing expression 440
# Doing expression 450
# Doing expression 460
# Doing expression 470
# Doing expression 480
# Doing expression 490
# Doing expression 500
# Doing expression 510
# Doing expression 520
# Doing expression 530
# Doing expression 540
# Doing expression 550
# Doing expression 560
# Doing expression 570
# Doing expression 580
# Doing expression 590
# Doing expression 600
# Doing expression 610
# Doing expression 620
# Doing expression 630
# Doing expression 640
# Doing expression 650
# Doing expression 660
# Doing expression 670
# Doing expression 680
# Doing expression 690
# Doing expression 700
# Doing expression 710
# Doing expression 720
# Doing expression 730
# Doing expression 740
# Doing expression 750
# Doing expression 760
# Doing expression 770
# Doing expression 780
# Doing expression 790
# Doing expression 800
# Doing expression 810
# Doing expression 820
# Doing expression 830
# Doing expression 840
# Doing expression 850
# Doing expression 860
# Doing expression 870
# Doing expression 880
# Doing expression 890
# Doing expression 900
# Doing expression 910
# Doing expression 920
# Doing expression 930
# Doing expression 940
# Doing expression 950
# Doing expression 960
# Doing expression 970
# Doing expression 980
# Doing expression 990
# Doing expression 1000
# Doing expression 1010
# Doing expression 1020
# Doing expression 1030
# Doing expression 1040
# Doing expression 1050
# Doing expression 1060
# Doing expression 1070
# Doing expression 1080
# Doing expression 1090
# Doing expression 1100
# Doing expression 1110
# Doing expression 1120
# Doing expression 1130
# Doing expression 1140
# Doing expression 1150
# Doing expression 1160
# Doing expression 1170
# Doing expression 1180
# Doing expression 1190
# Doing expression 1200
# Doing expression 1210
# Doing expression 1220
# Doing expression 1230
# Doing expression 1240
# Doing expression 1250
# Doing expression 1260
# Doing expression 1270
# Doing expression 1280
# Doing expression 1290
# Doing expression 1300
# Doing expression 1310
# Doing expression 1320
# Doing expression 1330
# Doing expression 1340
# Doing expression 1350
# Doing expression 1360
# Doing expression 1370
# Doing expression 1380
# Doing expression 1390
# Doing expression 1400
# Doing expression 1410
# Doing expression 1420
# Doing expression 1430
# Doing expression 1440
# Doing expression 1450
# Doing expression 1460
# Doing expression 1470
# Doing expression 1480
# Mean Total reward: 1.486158001350439
# Mean Total Steps: 27.86090479405807
# Mean Total Non cyclic Steps: 25.055367994598246
# Action distribution: {'0': 16944, '1': 8774, '2': 4155, '3': 11389}
# Mean Total Steps for solved: 6.398936170212766
# Mean Total Non cyclic Steps for solved: 5.299202127659575
# Action distribution for solved: {'0': 1768, '1': 1156, '2': 827, '3': 1061}
# Mean final number of polylogs: 2.475354490209318
# Mean initial number of polylogs : 4.87711006076975
# Mean final number of polylogs extra: 2.475354490209318
# Mean final length of expression: 90.5185685347738
# Mean initial length of expression: 140.17960837272113
# Mean final length of expression extra: 88.5185685347738
# Found 0 cyclic trajectories. So for 0 % of the expressions:
# Distribution for solved by initial length: {'0': 0.51, '1': 0, '2': 0, '3': 0}
# Distribution for solved in trajectory by initial length: {'0': 0.51, '1': 0, '2': 0, '3': 0}
# Distribution for solved: {'s1t1': 95.0, 's2t1': 69.0, 's2t2': 82.0, 's3t1': 61.0, 's3t2': 55.0, 's3t3': 63.0, 's4t1': 40.21, 's4t2': 41.0, 's4t3': 45.0, 's4t4': 59.0, 's5t1': 27.37, 's5t2': 34.34, 's6t1': 27.55, 's6t2': 31.31, 's7t1': 26.88}
# Distribution for solved in trajectory: {'s1t1': 95.0, 's2t1': 69.0, 's2t2': 82.0, 's3t1': 61.0, 's3t2': 55.0, 's3t3': 63.0, 's4t1': 40.21, 's4t2': 41.0, 's4t3': 45.0, 's4t4': 59.0, 's5t1': 27.37, 's5t2': 34.34, 's6t1': 27.55, 's6t2': 31.31, 's7t1': 26.88}
# Distribution for solved (non cyclic) steps: {'s1t1': 1.75, 's2t1': 3.75, 's2t2': 3.87, 's3t1': 4.48, 's3t2': 6.11, 's3t3': 5.84, 's4t1': 5.82, 's4t2': 6.95, 's4t3': 7.67, 's4t4': 7.53, 's5t1': 5.27, 's5t2': 8.44, 's6t1': 4.96, 's6t2': 8.52, 's7t1': 5.72}
# Distribution for nodes visited: {'s1t1': 4.14, 's2t1': 16.94, 's2t2': 11.54, 's3t1': 21.36, 's3t2': 23.66, 's3t3': 20.78, 's4t1': 29.855670103092784, 's4t2': 29.52, 's4t3': 27.58, 's4t4': 22.75, 's5t1': 34.44210526315789, 's5t2': 32.14141414141414, 's6t1': 34.285714285714285, 's6t2': 33.45454545454545, 's7t1': 35.03225806451613}
# Solved expressions, num polylogs 50 %
# Solved expressions, num words 50 %

# %%
if __name__ == '__main__':

    # Episode length
    max_step = 50

    # Reward function to use
    reward_func = StepReward(len_pen=0.01, num_terms_pen=0.1, active_pen=True, simple_reward=1, pen_cycle=True)

    # Define the environment and spaces
    x = sp.Symbol('x')
    exprtest = polylog(2, x)
    obs_space = StringObs(exprtest, 512, one_hot_encode=True, numeral_decomp=True, prev_st_info=True,
                          reduced_graph=True)
    act_space = ActionSpace(['inversion', 'reflection', 'cyclic', 'duplication'])
    rng = np.random.RandomState(1)
    env = PolyLogLinExpr(max_step, reward_func, obs_space, act_space, rng)

    # Load the model
    rl_model = TRPO.load("/home/stringer/Downloads/RL_agents_all/RL Agents/One_hot_cyclic_penalty.zip")

    # Load the test set
    start_set = "/home/stringer/Downloads/rl_data_dilogs/test_data.txt"

    # Evaluate the model and print the statistics
    evaluate_model(rl_model, env, initial_start_set=start_set, deterministic=True, num_runs=1, verbose=False,
                   random_agent=False, distrib_info=True)
# Out:
# On set :
# Doing expression 0
# Doing expression 10
# Doing expression 20
# Doing expression 30
# Doing expression 40
# Doing expression 50
# Doing expression 60
# Doing expression 70
# Doing expression 80
# Doing expression 90
# Doing expression 100
# Doing expression 110
# Doing expression 120
# Doing expression 130
# Doing expression 140
# Doing expression 150
# Doing expression 160
# Doing expression 170
# Doing expression 180
# Doing expression 190
# Doing expression 200
# Doing expression 210
# Doing expression 220
# Doing expression 230
# Doing expression 240
# Doing expression 250
# Doing expression 260
# Doing expression 270
# Doing expression 280
# Doing expression 290
# Doing expression 300
# Doing expression 310
# Doing expression 320
# Doing expression 330
# Doing expression 340
# Doing expression 350
# Doing expression 360
# Doing expression 370
# Doing expression 380
# Doing expression 390
# Doing expression 400
# Doing expression 410
# Doing expression 420
# Doing expression 430
# Doing expression 440
# Doing expression 450
# Doing expression 460
# Doing expression 470
# Doing expression 480
# Doing expression 490
# Doing expression 500
# Doing expression 510
# Doing expression 520
# Doing expression 530
# Doing expression 540
# Doing expression 550
# Doing expression 560
# Doing expression 570
# Doing expression 580
# Doing expression 590
# Doing expression 600
# Doing expression 610
# Doing expression 620
# Doing expression 630
# Doing expression 640
# Doing expression 650
# Doing expression 660
# Doing expression 670
# Doing expression 680
# Doing expression 690
# Doing expression 700
# Doing expression 710
# Doing expression 720
# Doing expression 730
# Doing expression 740
# Doing expression 750
# Doing expression 760
# Doing expression 770
# Doing expression 780
# Doing expression 790
# Doing expression 800
# Doing expression 810
# Doing expression 820
# Doing expression 830
# Doing expression 840
# Doing expression 850
# Doing expression 860
# Doing expression 870
# Doing expression 880
# Doing expression 890
# Doing expression 900
# Doing expression 910
# Doing expression 920
# Doing expression 930
# Doing expression 940
# Doing expression 950
# Doing expression 960
# Doing expression 970
# Doing expression 980
# Doing expression 990
# Doing expression 1000
# Doing expression 1010
# Doing expression 1020
# Doing expression 1030
# Doing expression 1040
# Doing expression 1050
# Doing expression 1060
# Doing expression 1070
# Doing expression 1080
# Doing expression 1090
# Doing expression 1100
# Doing expression 1110
# Doing expression 1120
# Doing expression 1130
# Doing expression 1140
# Doing expression 1150
# Doing expression 1160
# Doing expression 1170
# Doing expression 1180
# Doing expression 1190
# Doing expression 1200
# Doing expression 1210
# Doing expression 1220
# Doing expression 1230
# Doing expression 1240
# Doing expression 1250
# Doing expression 1260
# Doing expression 1270
# Doing expression 1280
# Doing expression 1290
# Doing expression 1300
# Doing expression 1310
# Doing expression 1320
# Doing expression 1330
# Doing expression 1340
# Doing expression 1350
# Doing expression 1360
# Doing expression 1370
# Doing expression 1380
# Doing expression 1390
# Doing expression 1400
# Doing expression 1410
# Doing expression 1420
# Doing expression 1430
# Doing expression 1440
# Doing expression 1450
# Doing expression 1460
# Doing expression 1470
# Doing expression 1480
# Mean Total reward: -55.72377447670493
# Mean Total Steps: 25.96556380823768
# Mean Total Non cyclic Steps: 17.095205941931127
# Action distribution: {'0': 10981, '1': 4382, '2': 13137, '3': 9955}
# Mean Total Steps for solved: 9.870349492671927
# Mean Total Non cyclic Steps for solved: 7.3585118376550165
# Action distribution for solved: {'0': 3048, '1': 1675, '2': 2228, '3': 1804}
# Mean final number of polylogs: 2.1991897366644158
# Mean initial number of polylogs : 4.87711006076975
# Mean final number of polylogs extra: 2.1991897366644158
# Mean final length of expression: 91.03646185010129
# Mean initial length of expression: 140.17960837272113
# Mean final length of expression extra: 89.03646185010129
# Found 1362 cyclic trajectories. So for 91 % of the expressions:
# Distribution for solved by initial length: {'0': 0.6, '1': 0, '2': 0, '3': 0}
# Distribution for solved in trajectory by initial length: {'0': 0.6, '1': 0, '2': 0, '3': 0}
# Distribution for solved: {'s1t1': 99.0, 's2t1': 83.0, 's2t2': 88.0, 's3t1': 68.0, 's3t2': 80.0, 's3t3': 70.0, 's4t1': 44.33, 's4t2': 55.0, 's4t3': 57.0, 's4t4': 56.0, 's5t1': 37.89, 's5t2': 48.48, 's6t1': 33.67, 's6t2': 36.36, 's7t1': 37.63}
# Distribution for solved in trajectory: {'s1t1': 99.0, 's2t1': 83.0, 's2t2': 88.0, 's3t1': 68.0, 's3t2': 80.0, 's3t3': 70.0, 's4t1': 44.33, 's4t2': 55.0, 's4t3': 57.0, 's4t4': 56.0, 's5t1': 37.89, 's5t2': 48.48, 's6t1': 33.67, 's6t2': 36.36, 's7t1': 37.63}
# Distribution for solved (non cyclic) steps: {'s1t1': 2.65, 's2t1': 4.24, 's2t2': 4.75, 's3t1': 5.59, 's3t2': 7.78, 's3t3': 8.67, 's4t1': 7.47, 's4t2': 9.04, 's4t3': 10.58, 's4t4': 10.8, 's5t1': 9.89, 's5t2': 10.46, 's6t1': 10.21, 's6t2': 10.72, 's7t1': 7.97}
# Distribution for nodes visited: {'s1t1': 3.05, 's2t1': 8.34, 's2t2': 8.24, 's3t1': 14.37, 's3t2': 12.98, 's3t3': 15.94, 's4t1': 20.97938144329897, 's4t2': 20.48, 's4t3': 19.88, 's4t4': 19.4, 's5t1': 22.378947368421052, 's5t2': 22.616161616161616, 's6t1': 23.540816326530614, 's6t2': 22.91919191919192, 's7t1': 22.301075268817204}
# Solved expressions, num polylogs 59 %
# Solved expressions, num words 59 %

# %%
if __name__ == '__main__':

    # Episode length
    max_step = 50

    # Reward function to use
    reward_func = StepReward(len_pen=0.01, num_terms_pen=0.1, active_pen=True, simple_reward=1, pen_cycle=True)

    # Define the environment and spaces
    x = sp.Symbol('x')
    exprtest = polylog(2, x)
    obs_space = StringObs(exprtest, 512, one_hot_encode=True, numeral_decomp=True, prev_st_info=True,
                          reduced_graph=True)
    act_space = ActionSpace(['inversion', 'reflection', 'cyclic', 'duplication'])
    rng = np.random.RandomState(1)
    env = PolyLogLinExpr(max_step, reward_func, obs_space, act_space, rng)

    # Load the model
    rl_model = TRPO.load("/home/stringer/Downloads/RL_agents_all/RL Agents/GNN_cyclic_penalty.zip")

    # Load the test set
    start_set = "/home/stringer/Downloads/rl_data_dilogs/test_data.txt"

    # Evaluate the model and print the statistics
    evaluate_model(rl_model, env, initial_start_set=start_set, deterministic=True, num_runs=1, verbose=False,
                   random_agent=False, distrib_info=True)
# Out:
# On set :
# Doing expression 0
# Doing expression 10
# Doing expression 20
# Doing expression 30
# Doing expression 40
# Doing expression 50
# Doing expression 60
# Doing expression 70
# Doing expression 80
# Doing expression 90
# Doing expression 100
# Doing expression 110
# Doing expression 120
# Doing expression 130
# Doing expression 140
# Doing expression 150
# Doing expression 160
# Doing expression 170
# Doing expression 180
# Doing expression 190
# Doing expression 200
# Doing expression 210
# Doing expression 220
# Doing expression 230
# Doing expression 240
# Doing expression 250
# Doing expression 260
# Doing expression 270
# Doing expression 280
# Doing expression 290
# Doing expression 300
# Doing expression 310
# Doing expression 320
# Doing expression 330
# Doing expression 340
# Doing expression 350
# Doing expression 360
# Doing expression 370
# Doing expression 380
# Doing expression 390
# Doing expression 400
# Doing expression 410
# Doing expression 420
# Doing expression 430
# Doing expression 440
# Doing expression 450
# Doing expression 460
# Doing expression 470
# Doing expression 480
# Doing expression 490
# Doing expression 500
# Doing expression 510
# Doing expression 520
# Doing expression 530
# Doing expression 540
# Doing expression 550
# Doing expression 560
# Doing expression 570
# Doing expression 580
# Doing expression 590
# Doing expression 600
# Doing expression 610
# Doing expression 620
# Doing expression 630
# Doing expression 640
# Doing expression 650
# Doing expression 660
# Doing expression 670
# Doing expression 680
# Doing expression 690
# Doing expression 700
# Doing expression 710
# Doing expression 720
# Doing expression 730
# Doing expression 740
# Doing expression 750
# Doing expression 760
# Doing expression 770
# Doing expression 780
# Doing expression 790
# Doing expression 800
# Doing expression 810
# Doing expression 820
# Doing expression 830
# Doing expression 840
# Doing expression 850
# Doing expression 860
# Doing expression 870
# Doing expression 880
# Doing expression 890
# Doing expression 900
# Doing expression 910
# Doing expression 920
# Doing expression 930
# Doing expression 940
# Doing expression 950
# Doing expression 960
# Doing expression 970
# Doing expression 980
# Doing expression 990
# Doing expression 1000
# Doing expression 1010
# Doing expression 1020
# Doing expression 1030
# Doing expression 1040
# Doing expression 1050
# Doing expression 1060
# Doing expression 1070
# Doing expression 1080
# Doing expression 1090
# Doing expression 1100
# Doing expression 1110
# Doing expression 1120
# Doing expression 1130
# Doing expression 1140
# Doing expression 1150
# Doing expression 1160
# Doing expression 1170
# Doing expression 1180
# Doing expression 1190
# Doing expression 1200
# Doing expression 1210
# Doing expression 1220
# Doing expression 1230
# Doing expression 1240
# Doing expression 1250
# Doing expression 1260
# Doing expression 1270
# Doing expression 1280
# Doing expression 1290
# Doing expression 1300
# Doing expression 1310
# Doing expression 1320
# Doing expression 1330
# Doing expression 1340
# Doing expression 1350
# Doing expression 1360
# Doing expression 1370
# Doing expression 1380
# Doing expression 1390
# Doing expression 1400
# Doing expression 1410
# Doing expression 1420
# Doing expression 1430
# Doing expression 1440
# Doing expression 1450
# Doing expression 1460
# Doing expression 1470
# Doing expression 1480
# ---------------------------------------------------------------------------
# ZeroDivisionError                         Traceback (most recent call last)
# Cell In[16], line 25
#      22 start_set = "/home/stringer/Downloads/rl_data_dilogs/test_data.txt"
#      24 # Evaluate the model and print the statistics
# ---> 25 evaluate_model(rl_model, env, initial_start_set=start_set, deterministic=True, num_runs=1, verbose=False,
#      26                random_agent=False, distrib_info=True)
#
# File ~/mycode/ML/try/ML_Polylogarithms-master/RL_Dilogs/model/monitor_utils.py:378, in evaluate_model(model, env, initial_start_set, deterministic, num_runs, verbose, random_agent, non_solved_set, distrib_info)
#     376 if distrib_info:
#     377     for key, value in dict_steps_taken.items():
# --> 378         dict_steps_taken[key] = round(value/dict_valid_count[key], 2)
#     379     for key, value in dict_valid_count.items():
#     380         dict_valid_count[key] = round(value*100 / dict_eq_done[key], 2)
#
# ZeroDivisionError: division by zero
