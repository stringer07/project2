# %%
"""
File to run and test the classical algorithm as well as the reinforcement learning models
"""
import numpy as np
import sympy as sp
from model.monitor_utils import search_algo_set
from sb3_contrib import TRPO
from rewards.reward_func import StepReward, EndReward
from observations.spaces import StringObs, ActionSpace
from envs.gym_env import PolyLogLinExpr

# %%
if __name__ == '__main__':

    start_set = '/home/stringer/Downloads/rl_data_dilogs/test_data.txt'

    # Define the reward and episode length
    reward_func = StepReward(len_pen=0.00, num_terms_pen=0.0, simple_reward=1, active_pen=False, pen_cycle=False)
    episode_length = 50

    # Define the observation and action spaces
    obs_space = StringObs(sp.polylog(2, sp.Symbol('x')), 512, one_hot_encode=True, numeral_decomp=True,
                          prev_st_info=True, reduced_graph=True)
    act_space = ActionSpace(['inversion', 'reflection', 'cyclic', 'duplication'])
    rng = np.random.RandomState(1)
    env = PolyLogLinExpr(episode_length, reward_func, obs_space, act_space, rng)

    # Load the model
    rl_model = TRPO.load("/home/stringer/Downloads/RL_agents_all/RL Agents/GNN_cyclic_penalty.zip")

    name = ['base', 'cyclic', 'base_gnn', 'cyclic_gnn']

    _ = search_algo_set(start_set, type_algo='beam_search', verbose=False, distrib_info=True,
                        model=rl_model, env=env, beam_size=3, breadth_size=2, gamma=0.9)

    _ = search_algo_set(start_set, type_algo='beam_search', verbose=False, distrib_info=True,
                        model=rl_model, env=env, beam_size=1, breadth_size=1, gamma=0.9)

    _ = search_algo_set(start_set, type_algo='classical', verbose=False, distrib_info=True,
                        tree_depth=10, beam_size=1, complex_ops=False)
# Out:
# On set : /home/stringer/Downloads/rl_data_dilogs/test_data.txt
# Doing expression 0
# Doing expression 10
# Doing expression 20
# Doing expression 30
# Doing expression 40
# Doing expression 50
# Doing expression 60
# Doing expression 70
# Doing expression 80
# Doing expression 90
# Doing expression 100
# Doing expression 110
# Doing expression 120
# Doing expression 130
# Doing expression 140
# Doing expression 150
# Doing expression 160
# Doing expression 170
# Doing expression 180
# Doing expression 190
# Doing expression 200
# Doing expression 210
# Doing expression 220
# Doing expression 230
# Doing expression 240
# Doing expression 250
# Doing expression 260
# Doing expression 270
# Doing expression 280
# Doing expression 290
# Doing expression 300
# Doing expression 310
# Doing expression 320
# Doing expression 330
# Doing expression 340
# Doing expression 350
# Doing expression 360
# Doing expression 370
# Doing expression 380
# Doing expression 390
# Doing expression 400
# Doing expression 410
# Doing expression 420
# Doing expression 430
# Doing expression 440
# Doing expression 450
# Doing expression 460
# Doing expression 470
# Doing expression 480
# Doing expression 490
# Doing expression 500
# Doing expression 510
# Doing expression 520
# Doing expression 530
# Doing expression 540
# Doing expression 550
# Doing expression 560
# Doing expression 570
# Doing expression 580
# Doing expression 590
# Doing expression 600
# Doing expression 610
# Doing expression 620
# Doing expression 630
# Doing expression 640
# Doing expression 650
# Doing expression 660
# Doing expression 670
# Doing expression 680
# Doing expression 690
# Doing expression 700
# Doing expression 710
# Doing expression 720
# Doing expression 730
# Doing expression 740
# Doing expression 750
# Doing expression 760
# Doing expression 770
# Doing expression 780
# Doing expression 790
# Doing expression 800
# Doing expression 810
# Doing expression 820
# Doing expression 830
# Doing expression 840
# Doing expression 850
# Doing expression 860
# Doing expression 870
# Doing expression 880
# Doing expression 890
# Doing expression 900
# Doing expression 910
# Doing expression 920
# Doing expression 930
# Doing expression 940
# Doing expression 950
# Doing expression 960
# Doing expression 970
# Doing expression 980
# Doing expression 990
# Doing expression 1000
# Doing expression 1010
# Doing expression 1020
# Doing expression 1030
# Doing expression 1040
# Doing expression 1050
# Doing expression 1060
# Doing expression 1070
# Doing expression 1080
# Doing expression 1090
# Doing expression 1100
# Doing expression 1110
# Doing expression 1120
# Doing expression 1130
# Doing expression 1140
# Doing expression 1150
# Doing expression 1160
# Doing expression 1170
# Doing expression 1180
# Doing expression 1190
# Doing expression 1200
# Doing expression 1210
# Doing expression 1220
# Doing expression 1230
# Doing expression 1240
# Doing expression 1250
# Doing expression 1260
# Doing expression 1270
# Doing expression 1280
# Doing expression 1290
# Doing expression 1300
# Doing expression 1310
# Doing expression 1320
# Doing expression 1330
# Doing expression 1340
# Doing expression 1350
# Doing expression 1360
# Doing expression 1370
# Doing expression 1380
# Doing expression 1390
# Doing expression 1400
# Doing expression 1410
# Doing expression 1420
# Doing expression 1430
# Doing expression 1440
# Doing expression 1450
# Doing expression 1460
# Doing expression 1470
# Doing expression 1480
# Mean final number of polylogs: 3.5050641458474003
# Mean initial number of polylogs : 4.87711006076975
# Mean final number of polylogs extra: 3.5050641458474003
# Mean number of identity used: 37.97771775827144
# Distribution for solved: {'s1t1': 64, 's2t1': 34, 's2t2': 56, 's3t1': 23, 's3t2': 42, 's3t3': 26, 's4t1': 17, 's4t2': 16, 's4t3': 21, 's4t4': 20, 's5t1': 16, 's5t2': 10, 's6t1': 8, 's6t2': 8, 's7t1': 14}
# Distribution for solved steps: {'s1t1': 1.0, 's2t1': 2.0588235294117645, 's2t2': 2.0357142857142856, 's3t1': 2.8260869565217392, 's3t2': 3.0476190476190474, 's3t3': 3.076923076923077, 's4t1': 2.0588235294117645, 's4t2': 3.75, 's4t3': 4.190476190476191, 's4t4': 4.05, 's5t1': 2.1875, 's5t2': 3.8, 's6t1': 3.5, 's6t2': 3.5, 's7t1': 3.142857142857143}
# Distribution of nodes visited: {'s1t1': 106.78, 's2t1': 195.23, 's2t2': 131.43, 's3t1': 228.24, 's3t2': 174.03, 's3t3': 219.17, 's4t1': 243.2164948453608, 's4t2': 249.06, 's4t3': 235.35, 's4t4': 237.95, 's5t1': 245.38947368421051, 's5t2': 265.5959595959596, 's6t1': 270.85714285714283, 's6t2': 270.9191919191919, 's7t1': 251.32258064516128}
# Distribution of nodes visited for solved: {'s1t1': 1.515625, 's2t1': 4.882352941176471, 's2t2': 3.7142857142857144, 's3t1': 8.347826086956522, 's3t2': 8.476190476190476, 's3t3': 8.0, 's4t1': 4.705882352941177, 's4t2': 13.125, 's4t3': 14.714285714285714, 's4t4': 13.8, 's5t1': 5.5625, 's5t2': 13.0, 's6t1': 13.5, 's6t2': 11.625, 's7t1': 10.5}
# Mean number of identity used for solved: 2.554666666666667
# Mean number of nodes visited for solved: 7.117333333333334
# Solved expressions, num polylogs 25 %
# On set : /home/stringer/Downloads/rl_data_dilogs/test_data.txt
# Doing expression 0
# Doing expression 10
# Doing expression 20
# Doing expression 30
# Doing expression 40
# Doing expression 50
# Doing expression 60
# Doing expression 70
# Doing expression 80
# Doing expression 90
# Doing expression 100
# Doing expression 110
# Doing expression 120
# Doing expression 130
# Doing expression 140
# Doing expression 150
# Doing expression 160
# Doing expression 170
# Doing expression 180
# Doing expression 190
# Doing expression 200
# Doing expression 210
# Doing expression 220
# Doing expression 230
# Doing expression 240
# Doing expression 250
# Doing expression 260
# Doing expression 270
# Doing expression 280
# Doing expression 290
# Doing expression 300
# Doing expression 310
# Doing expression 320
# Doing expression 330
# Doing expression 340
# Doing expression 350
# Doing expression 360
# Doing expression 370
# Doing expression 380
# Doing expression 390
# Doing expression 400
# Doing expression 410
# Doing expression 420
# Doing expression 430
# Doing expression 440
# Doing expression 450
# Doing expression 460
# Doing expression 470
# Doing expression 480
# Doing expression 490
# Doing expression 500
# Doing expression 510
# Doing expression 520
# Doing expression 530
# Doing expression 540
# Doing expression 550
# Doing expression 560
# Doing expression 570
# Doing expression 580
# Doing expression 590
# Doing expression 600
# Doing expression 610
# Doing expression 620
# Doing expression 630
# Doing expression 640
# Doing expression 650
# Doing expression 660
# Doing expression 670
# Doing expression 680
# Doing expression 690
# Doing expression 700
# Doing expression 710
# Doing expression 720
# Doing expression 730
# Doing expression 740
# Doing expression 750
# Doing expression 760
# Doing expression 770
# Doing expression 780
# Doing expression 790
# Doing expression 800
# Doing expression 810
# Doing expression 820
# Doing expression 830
# Doing expression 840
# Doing expression 850
# Doing expression 860
# Doing expression 870
# Doing expression 880
# Doing expression 890
# Doing expression 900
# Doing expression 910
# Doing expression 920
# Doing expression 930
# Doing expression 940
# Doing expression 950
# Doing expression 960
# Doing expression 970
# Doing expression 980
# Doing expression 990
# Doing expression 1000
# Doing expression 1010
# Doing expression 1020
# Doing expression 1030
# Doing expression 1040
# Doing expression 1050
# Doing expression 1060
# Doing expression 1070
# Doing expression 1080
# Doing expression 1090
# Doing expression 1100
# Doing expression 1110
# Doing expression 1120
# Doing expression 1130
# Doing expression 1140
# Doing expression 1150
# Doing expression 1160
# Doing expression 1170
# Doing expression 1180
# Doing expression 1190
# Doing expression 1200
# Doing expression 1210
# Doing expression 1220
# Doing expression 1230
# Doing expression 1240
# Doing expression 1250
# Doing expression 1260
# Doing expression 1270
# Doing expression 1280
# Doing expression 1290
# Doing expression 1300
# Doing expression 1310
# Doing expression 1320
# Doing expression 1330
# Doing expression 1340
# Doing expression 1350
# Doing expression 1360
# Doing expression 1370
# Doing expression 1380
# Doing expression 1390
# Doing expression 1400
# Doing expression 1410
# Doing expression 1420
# Doing expression 1430
# Doing expression 1440
# Doing expression 1450
# Doing expression 1460
# Doing expression 1470
# Doing expression 1480
# ---------------------------------------------------------------------------
# ZeroDivisionError                         Traceback (most recent call last)
# Cell In[2], line 24
#      19 name = ['base', 'cyclic', 'base_gnn', 'cyclic_gnn']
#      21 _ = search_algo_set(start_set, type_algo='beam_search', verbose=False, distrib_info=True,
#      22                     model=rl_model, env=env, beam_size=3, breadth_size=2, gamma=0.9)
# ---> 24 _ = search_algo_set(start_set, type_algo='beam_search', verbose=False, distrib_info=True,
#      25                     model=rl_model, env=env, beam_size=1, breadth_size=1, gamma=0.9)
#      27 _ = search_algo_set(start_set, type_algo='classical', verbose=False, distrib_info=True,
#      28                     tree_depth=10, beam_size=1, complex_ops=False)
#
# File ~/mycode/ML/try/ML_Polylogarithms-master/RL_Dilogs/model/monitor_utils.py:580, in search_algo_set(initial_set, type_algo, verbose, distrib_info, **kwargs)
#     578 if distrib_info:
#     579     for key, value in dict_steps_taken.items():
# --> 580         dict_steps_taken[key] = value/dict_valid_count[key]
#     581     for key, value in dict_nodes.items():
#     582         dict_nodes[key] = value/dict_eqs[key]
#
# ZeroDivisionError: division by zero
